# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
latrocinios = pd.read_excel('Latrocinio_2018_2022.xlsx', engine='openpyxl')
latrocinios
# Out:
#     DEPARTAMENTO_CIRCUNSCRICAO SECCIONAL_CIRCUNSCRICAO  \
# 0                        DECAP                  1ª SEC
# 1                        DECAP                  3ª SEC
# 2                        DECAP                  3ª SEC
# 3                        DECAP                  6ª SEC
# 4                        DECAP                  8ª SEC
# ..                         ...                     ...
# 273                    DEMACRO     SEC Mogi das Cruzes
# 274                    DEMACRO     SEC Mogi das Cruzes
# 275                    DEMACRO              SEC Osasco
# 276                    DEMACRO              SEC Osasco
# 277                    DEMACRO         SEC Santo André
#
#     MUNICIPIO_CIRCUNSCRICAO              DP_CIRCUNSCRICAO   LATRO  \
# 0                 São Paulo             005 DP - Aclimação    1.0
# 1                 São Paulo           037 DP - Campo Limpo    1.0
# 2                 São Paulo           037 DP - Campo Limpo    1.0
# ...

# %% [markdown]
# Remover null/nan

# %%
latrocinios.dropna(inplace=True)
latrocinios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 0 to 277
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DEPARTAMENTO_CIRCUNSCRICAO  173 non-null    object
#  1   SECCIONAL_CIRCUNSCRICAO     173 non-null    object
#  2   MUNICIPIO_CIRCUNSCRICAO     173 non-null    object
#  3   DP_CIRCUNSCRICAO            173 non-null    object
#  4   LATRO                       173 non-null    float64
#  5   Nº DE VIT EM LATRO          173 non-null    int64
#  6   ID_DELEGACIA                173 non-null    int64
#  7   MÊS ESTATISTICA             173 non-null    int64
#  8   ANO ESTATISTICA             173 non-null    int64
#  9   DATAHORA_REGISTRO_BO        173 non-null    datetime64[ns]
#  10  NUM_BO                      173 non-null    int64
#  11  ANO_BO                      173 non-null    int64
#  12  MUNICIPIO_ELABORACAO        173 non-null    object
# ...

# %% [markdown]
# Filtrar dado de São Paulo

# %%
municipio = latrocinios['MUNICIPIO_CIRCUNSCRICAO'] == 'São Paulo'
latrocinios[municipio]
# Out:
#     DEPARTAMENTO_CIRCUNSCRICAO SECCIONAL_CIRCUNSCRICAO  \
# 0                        DECAP                  1ª SEC
# 1                        DECAP                  3ª SEC
# 2                        DECAP                  3ª SEC
# 3                        DECAP                  6ª SEC
# 4                        DECAP                  8ª SEC
# 26                       DECAP                  3ª SEC
# 27                       DECAP                  3ª SEC
# 28                       DECAP                  4ª SEC
# 29                       DECAP                  6ª SEC
# 46                       DECAP                  1ª SEC
# 47                       DECAP                  3ª SEC
# 48                       DECAP                  4ª SEC
# 68                       DECAP                  2ª SEC
# 71                       DECAP                  4ª SEC
# 72                       DECAP                  6ª SEC
# 73                       DECAP                  6ª SEC
# ...

# %% [markdown]
# Transformar dados temporais(já estão no formato correto)

# %%
latrocinios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 0 to 277
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DEPARTAMENTO_CIRCUNSCRICAO  173 non-null    object
#  1   SECCIONAL_CIRCUNSCRICAO     173 non-null    object
#  2   MUNICIPIO_CIRCUNSCRICAO     173 non-null    object
#  3   DP_CIRCUNSCRICAO            173 non-null    object
#  4   LATRO                       173 non-null    float64
#  5   Nº DE VIT EM LATRO          173 non-null    int64
#  6   ID_DELEGACIA                173 non-null    int64
#  7   MÊS ESTATISTICA             173 non-null    int64
#  8   ANO ESTATISTICA             173 non-null    int64
#  9   DATAHORA_REGISTRO_BO        173 non-null    datetime64[ns]
#  10  NUM_BO                      173 non-null    int64
#  11  ANO_BO                      173 non-null    int64
#  12  MUNICIPIO_ELABORACAO        173 non-null    object
# ...

# %% [markdown]
# Grafico data nascimento

# %%
plt.style.use("ggplot")
plt.figure(figsize = (8,5))
latrocinios["IDADE_PESSOA"].hist()
# Out:
# <Axes: >
